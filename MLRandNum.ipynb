# %%
#program chooses a random paragraph for each chapter in a book
import random
import sys
import os

from random import seed
from random import randint
from datetime import datetime

random.seed(datetime.now())

for x in range(1):
  #change the range in the randint according to the number of paragraphs in each chapter
  value = randint(1, 15)
  print(value)
# Out:
# 10
